# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt

# %%
text="hello how are you where are you going"
word=WordCloud(background_color="white").generate(text)
plt.imshow(word)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import csv

file = open(r'/home/codetheocean/Documents/LCO/wordcloud.csv')
file_read = csv.reader(file)
file_list = list(file_read)
text = ""
for i in file_list:
    for word in i:
        text = text + " " + word
word = WordCloud(background_color="white").generate(text)
plt.imshow(word)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import csv

file = open(r'/home/codetheocean/Documents/LCO/wordcloud.csv')
file_read = csv.reader(file)
file_list = list(file_read)
text = ""
for i in file_list:
    for word in i:
        text = text + " " + word
word = WordCloud(width=1920 , height= 1080).generate(text)
plt.imshow(word)
plt.axis("off")
plt.show()
plt.imsave("123")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-29c4d6cc9977> in <module>
#      14 plt.axis("off")
#      15 plt.show()
# ---> 16 plt.imsave("123")
#
# TypeError: imsave() missing 1 required positional argument: 'arr'

# %%
from getpass import getpass
